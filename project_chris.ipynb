# %%
import pandas as pd 
from statsmodels.tsa.arima_model import ARMA, ARMAResults
from pandas.io.json import json_normalize
import sklearn.model_selection
from statsmodels.tsa.ar_model import AR
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# Import refugee data 
# DRC



df_all = pd.read_json("data/refugees from south-sudan all.json")
df_all = json_normalize((df.loc['timeseries', 'data']))
df_all['data_date'] = pd.to_datetime(df_drc['data_date'])
df_all['data_date'] = df_all['data_date'] + pd.offsets.MonthBegin(0)
df_all['data_date'] = df_all['data_date'].dt.strftime('%Y-%m')

df = pd.read_json("data/refugees to DRC.json")
df_drc = json_normalize((df.loc['timeseries', 'data']))
df_drc['data_date'] = pd.to_datetime(df_drc['data_date'])
df_drc['data_date'] = df_drc['data_date'] + pd.offsets.MonthBegin(0)
df_drc['data_date'] = df_drc['data_date'].dt.strftime('%Y-%m')

# Ethiopa
df = pd.read_json("data/refugees to Ethiopia.json")
df_ethiopia = json_normalize((df.loc['timeseries', 'data']))
df_ethiopia['data_date'] = pd.to_datetime(df_ethiopia['data_date'])
df_ethiopia['data_date'] = df_ethiopia['data_date'] + pd.offsets.MonthBegin(0)
df_ethiopia['data_date'] = df_ethiopia['data_date'].dt.strftime('%Y-%m')

# Kenya
df = pd.read_json("data/refugees to Kenya.json")
df_kenya = json_normalize((df.loc['timeseries', 'data']))
df_kenya['data_date'] = pd.to_datetime(df_kenya['data_date'])
df_kenya['data_date'] = df_kenya['data_date'] + pd.offsets.MonthBegin(0)
df_kenya['data_date'] = df_kenya['data_date'].dt.strftime('%Y-%m')

# Sudan
df = pd.read_json("data/refugees to Sudan.json")
df_sudan = json_normalize((df.loc['timeseries', 'data']))
df_sudan['data_date'] = pd.to_datetime(df_sudan['data_date'])
df_sudan['data_date'] = df_sudan['data_date'] + pd.offsets.MonthBegin(0)
df_sudan['data_date'] = df_sudan['data_date'].dt.strftime('%Y-%m')

# Uganda,
df = pd.read_json("data/refugees to Uganda.json")
df_uganda = json_normalize((df.loc['timeseries', 'data']))
df_uganda['data_date'] = pd.to_datetime(df_uganda['data_date'])
df_uganda['data_date'] = df_uganda['data_date'] + pd.offsets.MonthBegin(0)
df_uganda['data_date'] = df_uganda['data_date'].dt.strftime('%Y-%m')

dates = pd.concat([df_drc[['data_date']],df_ethiopia[['data_date']],df_kenya[['data_date']],df_sudan[['data_date']], df_uganda[['data_date']] ])

# dates = dates['data_date'].drop_duplicates().sort_values()

# df_uganda.head()



df_all.head()
# Out:
#   data_date  individuals  unix_timestamp
# 0   2014-11        12524      1356912000
# 1   2014-12        25274      1388448000
# 2   2015-01       118051      1396224000
# 3   2015-02       142766      1404086400
# 4   2015-03       150181      1412035200

# %%
plt = df_drc.plot(x='data_date', y='individuals')

plt = df_ethiopia.plot(x='data_date', y='individuals', ax=plt)

plt = df_kenya.plot(x='data_date', y='individuals', ax=plt)

plt = df_sudan.plot(x='data_date', y='individuals', ax=plt)

plt = df_uganda.plot(x='data_date', y='individuals', ax=plt)

plt.legend(['DRC', 'Ethiopia', 'Kenya', 'Sudan', 'Uganda'])

df_combined = [df_drc, df_ethiopia, df_kenya, df_sudan, df_uganda]

# %%
df_incidents = pd.read_csv("data/incidents.csv", delimiter=';')
df_incidents['fatalities'] = df_incidents.fatalities.fillna(0)
df_incidents['event_date'] = pd.to_datetime(df_incidents['event_date'])

df_incidents.head()
# Out:
#    event_id_no_cnty event_date                  event_type  \
# 0            5333.0 2018-09-11  Violence against civilians
# 1            5332.0 2018-06-11  Violence against civilians
# 2            5330.0 2018-02-11       Strategic development
# 3            5331.0 2018-02-11  Violence against civilians
# 4            5328.0 2018-10-31  Violence against civilians
#
#                                               actor1  inter1  \
# 0           Aluakluak Communal Militia (South Sudan)     4.0
# 1             Unidentified Armed Group (South Sudan)     3.0
# 2  SPLA/M-In Opposition: Sudanese Peoples Liberat...     2.0
# 3             Unidentified Armed Group (South Sudan)     3.0
# 4                 Murle Ethnic Militia (South Sudan)     4.0
#
#                               actor2  inter2      country   location  \
# 0            Civilians (South Sudan)     7.0  South Sudan       Akot
# 1            Civilians (South Sudan)     7.0  South Sudan        Wau
# 2  Government of South Sudan (2011-)     1.0  South Sudan       Juba
# 3            Civilians (South Sudan)     7.0  South Sudan  Tirangore
# 4            Civilians (South Sudan)     7.0  South Sudan      Jalle
#
#    fatalities
# 0         2.0
# 1         1.0
# 2         0.0
# 3         0.0
# 4         0.0

# %%
arr_event = []
for item in pd.unique(df_incidents['event_type']):
    df_tmp = df_incidents.loc[df_incidents['event_type'] == item]
    arr_event.append(df_tmp)
    
for item in arr_event:
    item.plot(x='event_date', y='fatalities')

# %%
df_incidents['event_date'] = pd.to_datetime(df_incidents['event_date'])
df_incidents['event_date'] = df_incidents['event_date'] + pd.offsets.MonthBegin(0)
df_incidents['event_date'] = df_incidents['event_date'].dt.strftime('%Y-%m')

df_incidents.head()
# Out:
#    event_id_no_cnty event_date                  event_type  \
# 0            5333.0    2018-10  Violence against civilians
# 1            5332.0    2018-07  Violence against civilians
# 2            5330.0    2018-03       Strategic development
# 3            5331.0    2018-03  Violence against civilians
# 4            5328.0    2018-11  Violence against civilians
#
#                                               actor1  inter1  \
# 0           Aluakluak Communal Militia (South Sudan)     4.0
# 1             Unidentified Armed Group (South Sudan)     3.0
# 2  SPLA/M-In Opposition: Sudanese Peoples Liberat...     2.0
# 3             Unidentified Armed Group (South Sudan)     3.0
# 4                 Murle Ethnic Militia (South Sudan)     4.0
#
#                               actor2  inter2      country   location  \
# 0            Civilians (South Sudan)     7.0  South Sudan       Akot
# 1            Civilians (South Sudan)     7.0  South Sudan        Wau
# 2  Government of South Sudan (2011-)     1.0  South Sudan       Juba
# 3            Civilians (South Sudan)     7.0  South Sudan  Tirangore
# 4            Civilians (South Sudan)     7.0  South Sudan      Jalle
#
#    fatalities
# 0         2.0
# 1         1.0
# 2         0.0
# 3         0.0
# 4         0.0

# %%
df_agg  = df_incidents[['event_date', 'fatalities']]
# df_agg2 = df_agg.groupby('event_date').sum()
# df_agg2.head()
# # df_agg2.plot()

df_agg  = df_incidents[['event_date', 'fatalities']]

#df_agg3 = df_agg

#df_agg3['fatalities'] = pd.Series.cumsum(df_agg3['fatalities'])

#df_agg3.plot()


df_agg2 = df_agg.groupby('event_date').sum()


df_agg2['fatalities'] = pd.Series.cumsum(df_agg2['fatalities'])


# df_agg2['fatalities'] = df_agg2['fatalities'] / df_agg2['fatalities'].max()

#df_agg2['event_date'] = pd.to_datetime(df_agg2['event_date'])

df_agg2.reset_index(inplace=True)
#df_agg2.plot(x='event_date', y='fatalities')
df_agg2['event_date'] = pd.to_datetime(df_agg2['event_date'])
# df_agg2
# Out:
#    event_date  fatalities
# 0  2011-04-01         0.0
# 1  2011-05-01         0.0
# 2  2011-06-01        37.0
# 3  2011-08-01        38.0
# 4  2011-09-01      1438.0
# 5  2011-10-01      1460.0
# 6  2011-11-01      1460.0
# 7  2011-12-01      1489.0
# 8  2012-01-01      1683.0
# 9  2012-02-01      1797.0
# 10 2012-03-01      2012.0
# 11 2012-04-01      2019.0
# 12 2012-05-01      2071.0
# 13 2012-06-01      2114.0
# 14 2012-07-01      2149.0
# 15 2012-08-01      2199.0
# 16 2012-09-01      2364.0
# 17 2012-10-01      2423.0
# 18 2012-11-01      2431.0
# 19 2012-12-01      2449.0
# 20 2013-01-01      2502.0
# 21 2013-02-01      2719.0
# 22 2013-03-01      2873.0
# 23 2013-04-01      3160.0
# 24 2013-05-01      3213.0
# 25 2013-06-01      3365.0
# 26 2013-07-01      3380.0
# 27 2013-08-01      3436.0
# 28 2013-09-01      3462.0
# 29 2013-10-01      3473.0
# ..        ...         ...
# 63 2016-08-01     12217.0
# 64 2016-09-01     12673.0
# 65 2016-10-01     12864.0
# 66 2016-11-01     13099.0
# 67 2016-12-01     13291.0
# 68 2017-01-01     13502.0
# 69 2017-02-01     13635.0
# 70 2017-03-01     13806.0
# 71 2017-04-01     13925.0
# 72 2017-05-01     14316.0
# 73 2017-06-01     14501.0
# 74 2017-07-01     14644.0
# 75 2017-08-01     14767.0
# 76 2017-09-01     14923.0
# 77 2017-10-01     15024.0
# 78 2017-11-01     15197.0
# 79 2017-12-01     15279.0
# 80 2018-01-01     15379.0
# 81 2018-02-01     15415.0
# 82 2018-03-01     15497.0
# 83 2018-04-01     15576.0
# 84 2018-05-01     15672.0
# 85 2018-06-01     15767.0
# 86 2018-07-01     15913.0
# 87 2018-08-01     15966.0
# 88 2018-09-01     16031.0
# 89 2018-10-01     16074.0
# 90 2018-11-01     16104.0
# 91 2018-12-01     16150.0
# 92 2019-01-01     16192.0
#
# [93 rows x 2 columns]

# %%
# Import food data
df_food = pd.read_csv("data/wfp_food_prices_south-sudan.csv")
df_food = df_food.drop(df_food.index[0])
df_food['date'] = pd.to_datetime(df_food['date'])
df_food['date'] = df_food['date'] + pd.offsets.MonthBegin(0)
df_food['date'] = df_food['date'].dt.strftime('%Y-%m')
df_food['date'] = pd.to_datetime(df_food['date'])
df_food['price'] = pd.to_numeric(df_food['price'])
#df_food['cmname'] = df_food['cmname'].astype('|S')

df_food
# Out:
#            date                              cmname    unit  \
# 1    2012-02-01              Fuel (diesel) - Retail       L
# 2    2012-03-01              Fuel (diesel) - Retail       L
# 3    2012-04-01              Fuel (diesel) - Retail       L
# 4    2012-05-01              Fuel (diesel) - Retail       L
# 5    2012-06-01              Fuel (diesel) - Retail       L
# 6    2012-07-01              Fuel (diesel) - Retail       L
# 7    2012-08-01              Fuel (diesel) - Retail       L
# 8    2012-09-01              Fuel (diesel) - Retail       L
# 9    2012-10-01              Fuel (diesel) - Retail       L
# 10   2012-11-01              Fuel (diesel) - Retail       L
# 11   2012-12-01              Fuel (diesel) - Retail       L
# 12   2013-01-01              Fuel (diesel) - Retail       L
# 13   2013-02-01              Fuel (diesel) - Retail       L
# 14   2013-03-01              Fuel (diesel) - Retail       L
# 15   2013-04-01              Fuel (diesel) - Retail       L
# 16   2013-05-01              Fuel (diesel) - Retail       L
# 17   2013-06-01              Fuel (diesel) - Retail       L
# 18   2013-07-01              Fuel (diesel) - Retail       L
# 19   2013-08-01              Fuel (diesel) - Retail       L
# 20   2013-09-01              Fuel (diesel) - Retail       L
# 21   2013-10-01              Fuel (diesel) - Retail       L
# 22   2013-11-01              Fuel (diesel) - Retail       L
# 23   2013-12-01              Fuel (diesel) - Retail       L
# 24   2014-01-01              Fuel (diesel) - Retail       L
# 25   2012-02-01     Fuel (petrol-gasoline) - Retail       L
# 26   2012-03-01     Fuel (petrol-gasoline) - Retail       L
# 27   2012-04-01     Fuel (petrol-gasoline) - Retail       L
# 28   2012-05-01     Fuel (petrol-gasoline) - Retail       L
# 29   2012-06-01     Fuel (petrol-gasoline) - Retail       L
# 30   2012-07-01     Fuel (petrol-gasoline) - Retail       L
# ...         ...                                 ...     ...
# 6290 2013-05-01  Sorghum (white, imported) - Retail  3.5 KG
# 6291 2013-06-01  Sorghum (white, imported) - Retail  3.5 KG
# 6292 2013-07-01  Sorghum (white, imported) - Retail  3.5 KG
# 6293 2013-08-01  Sorghum (white, imported) - Retail  3.5 KG
# 6294 2013-09-01  Sorghum (white, imported) - Retail  3.5 KG
# 6295 2013-10-01  Sorghum (white, imported) - Retail  3.5 KG
# 6296 2013-11-01  Sorghum (white, imported) - Retail  3.5 KG
# 6297 2013-12-01  Sorghum (white, imported) - Retail  3.5 KG
# 6298 2014-01-01  Sorghum (white, imported) - Retail  3.5 KG
# 6299 2014-09-01  Sorghum (white, imported) - Retail  3.5 KG
# 6300 2014-10-01  Sorghum (white, imported) - Retail  3.5 KG
# 6301 2014-11-01  Sorghum (white, imported) - Retail  3.5 KG
# 6302 2014-12-01  Sorghum (white, imported) - Retail  3.5 KG
# 6303 2015-01-01  Sorghum (white, imported) - Retail  3.5 KG
# 6304 2015-02-01  Sorghum (white, imported) - Retail  3.5 KG
# 6305 2015-03-01  Sorghum (white, imported) - Retail  3.5 KG
# 6306 2015-04-01  Sorghum (white, imported) - Retail  3.5 KG
# 6307 2015-05-01  Sorghum (white, imported) - Retail  3.5 KG
# 6308 2015-06-01  Sorghum (white, imported) - Retail  3.5 KG
# 6309 2015-07-01  Sorghum (white, imported) - Retail  3.5 KG
# 6310 2015-08-01  Sorghum (white, imported) - Retail  3.5 KG
# 6311 2015-09-01  Sorghum (white, imported) - Retail  3.5 KG
# 6312 2015-10-01  Sorghum (white, imported) - Retail  3.5 KG
# 6313 2015-11-01  Sorghum (white, imported) - Retail  3.5 KG
# 6314 2015-12-01  Sorghum (white, imported) - Retail  3.5 KG
# 6315 2016-02-01  Sorghum (white, imported) - Retail  3.5 KG
# 6316 2016-03-01  Sorghum (white, imported) - Retail  3.5 KG
# 6317 2016-05-01  Sorghum (white, imported) - Retail  3.5 KG
# 6318 2016-08-01  Sorghum (white, imported) - Retail  3.5 KG
# 6319 2018-04-01  Sorghum (white, imported) - Retail  3.5 KG
#
#                 category     price currency      country admname adm1id  \
# 1               non-food    7.9063      SSP  South Sudan     NaN      0
# 2               non-food    7.2750      SSP  South Sudan     NaN      0
# 3               non-food    7.4531      SSP  South Sudan     NaN      0
# 4               non-food    8.1719      SSP  South Sudan     NaN      0
# 5               non-food   11.9688      SSP  South Sudan     NaN      0
# 6               non-food   10.2656      SSP  South Sudan     NaN      0
# 7               non-food   10.3438      SSP  South Sudan     NaN      0
# 8               non-food   10.8125      SSP  South Sudan     NaN      0
# 9               non-food   10.1250      SSP  South Sudan     NaN      0
# 10              non-food   10.6875      SSP  South Sudan     NaN      0
# 11              non-food   10.4516      SSP  South Sudan     NaN      0
# 12              non-food   10.1875      SSP  South Sudan     NaN      0
# 13              non-food    9.6250      SSP  South Sudan     NaN      0
# 14              non-food    9.1875      SSP  South Sudan     NaN      0
# 15              non-food    9.2656      SSP  South Sudan     NaN      0
# 16              non-food    9.1071      SSP  South Sudan     NaN      0
# 17              non-food    8.7500      SSP  South Sudan     NaN      0
# 18              non-food    8.8333      SSP  South Sudan     NaN      0
# 19              non-food    8.7656      SSP  South Sudan     NaN      0
# 20              non-food    9.4286      SSP  South Sudan     NaN      0
# 21              non-food    9.0714      SSP  South Sudan     NaN      0
# 22              non-food    8.7857      SSP  South Sudan     NaN      0
# 23              non-food    8.8214      SSP  South Sudan     NaN      0
# 24              non-food    8.9643      SSP  South Sudan     NaN      0
# 25              non-food    9.9187      SSP  South Sudan     NaN      0
# 26              non-food    9.1406      SSP  South Sudan     NaN      0
# 27              non-food    8.6750      SSP  South Sudan     NaN      0
# 28              non-food   11.8438      SSP  South Sudan     NaN      0
# 29              non-food   14.3125      SSP  South Sudan     NaN      0
# 30              non-food   14.2581      SSP  South Sudan     NaN      0
# ...                  ...       ...      ...          ...     ...    ...
# 6290  cereals and tubers   12.2000      SSP  South Sudan     NaN  37021
# 6291  cereals and tubers   13.5000      SSP  South Sudan     NaN  37021
# 6292  cereals and tubers   21.7000      SSP  South Sudan     NaN  37021
# 6293  cereals and tubers   15.0000      SSP  South Sudan     NaN  37021
# 6294  cereals and tubers   15.0000      SSP  South Sudan     NaN  37021
# 6295  cereals and tubers   15.0000      SSP  South Sudan     NaN  37021
# 6296  cereals and tubers   15.0000      SSP  South Sudan     NaN  37021
# 6297  cereals and tubers   13.0000      SSP  South Sudan     NaN  37021
# 6298  cereals and tubers   12.7500      SSP  South Sudan     NaN  37021
# 6299  cereals and tubers   21.0000      SSP  South Sudan     NaN  37021
# 6300  cereals and tubers   21.5000      SSP  South Sudan     NaN  37021
# 6301  cereals and tubers   21.7500      SSP  South Sudan     NaN  37021
# 6302  cereals and tubers   25.0000      SSP  South Sudan     NaN  37021
# 6303  cereals and tubers   15.2000      SSP  South Sudan     NaN  37021
# 6304  cereals and tubers   13.0000      SSP  South Sudan     NaN  37021
# 6305  cereals and tubers   13.0000      SSP  South Sudan     NaN  37021
# 6306  cereals and tubers   13.0000      SSP  South Sudan     NaN  37021
# 6307  cereals and tubers   16.5000      SSP  South Sudan     NaN  37021
# 6308  cereals and tubers   22.5000      SSP  South Sudan     NaN  37021
# 6309  cereals and tubers   35.0000      SSP  South Sudan     NaN  37021
# 6310  cereals and tubers   51.7000      SSP  South Sudan     NaN  37021
# 6311  cereals and tubers   26.0000      SSP  South Sudan     NaN  37021
# 6312  cereals and tubers   25.0000      SSP  South Sudan     NaN  37021
# 6313  cereals and tubers   33.5000      SSP  South Sudan     NaN  37021
# 6314  cereals and tubers   33.2000      SSP  South Sudan     NaN  37021
# 6315  cereals and tubers   61.0000      SSP  South Sudan     NaN  37021
# 6316  cereals and tubers   30.0000      SSP  South Sudan     NaN  37021
# 6317  cereals and tubers   50.8000      SSP  South Sudan     NaN  37021
# 6318  cereals and tubers   70.0000      SSP  South Sudan     NaN  37021
# 6319  cereals and tubers  275.0000      SSP  South Sudan     NaN  37021
#
#                mktname   mktid cmid  ptid  umid catid              sn  default
# 1     National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 2     National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 3     National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 4     National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 5     National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 6     National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 7     National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 8     National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 9     National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 10    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 11    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 12    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 13    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 14    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 15    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 16    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 17    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 18    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 19    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 20    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 21    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 22    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 23    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 24    National Average  1199.0  284  15.0  15.0     8  1199_284_15_15      NaN
# 25    National Average  1199.0  285  15.0  15.0     8  1199_285_15_15      NaN
# 26    National Average  1199.0  285  15.0  15.0     8  1199_285_15_15      NaN
# 27    National Average  1199.0  285  15.0  15.0     8  1199_285_15_15      NaN
# 28    National Average  1199.0  285  15.0  15.0     8  1199_285_15_15      NaN
# 29    National Average  1199.0  285  15.0  15.0     8  1199_285_15_15      NaN
# 30    National Average  1199.0  285  15.0  15.0     8  1199_285_15_15      NaN
# ...                ...     ...  ...   ...   ...   ...             ...      ...
# 6290           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6291           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6292           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6293           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6294           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6295           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6296           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6297           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6298           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6299           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6300           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6301           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6302           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6303           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6304           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6305           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6306           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6307           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6308           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6309           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6310           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6311           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6312           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6313           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6314           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6315           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6316           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6317           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6318           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
# 6319           Malakal  1389.0  510  15.0  47.0     1  1389_510_15_47      NaN
#
# [6319 rows x 17 columns]

# %%
foodarray = []
for item in pd.unique(df_food['cmname']):
    df_tmp = df_food.loc[df_food['cmname'] == item]
    if df_tmp.shape[0] > 50:
        foodarray.append(df_tmp)
    
for item in foodarray:
    item.plot(x='date', y='price')

#fig, ax = plt.subplots()

# %%
# Food assumptions: All different types of food are eaten equally

normalized_foods = []

for item in pd.unique(df_food['cmname']):
    df_tmp = df_food.loc[df_food['cmname'] == item]
    if df_tmp.shape[0] > 120:
#         df_tmp['price'] = df_tmp['price']/df_tmp['price'].max()
        normalized_foods.append(df_tmp)
        

df_norm = pd.concat(normalized_foods)

df_norm = df_norm[['date', 'price']]
df_norm = df_norm.groupby(['date']).mean()
df_norm.reset_index(inplace=True)
df_norm['date'] = pd.to_datetime(df_norm['date'], format='%Y-%m-%d').apply(lambda x: x.strftime('%Y-%m'))
df_norm['date'] = pd.to_datetime(df_norm['date'])
df_norm = df_norm.loc[df_norm['date'] > '2014-12']
df_norm.plot(x='date', y='price')

df_norm
# Out:
#           date       price
# 106 2015-01-01   14.027907
# 107 2015-02-01   15.650000
# 108 2015-03-01   15.648649
# 109 2015-04-01   15.088889
# 110 2015-05-01   20.231000
# 111 2015-06-01   20.632258
# 112 2015-07-01   23.021667
# 113 2015-08-01   23.743443
# 114 2015-09-01   24.337705
# 115 2015-10-01   23.480508
# 116 2015-11-01   26.635185
# 117 2015-12-01   29.547115
# 118 2016-01-01   34.326042
# 119 2016-02-01   37.388514
# 120 2016-03-01   43.076429
# 121 2016-04-01   53.358904
# 122 2016-05-01   52.843506
# 123 2016-06-01   58.323239
# 124 2016-07-01   59.798370
# 125 2016-08-01   96.696812
# 126 2016-09-01  131.621026
# 127 2016-10-01  112.861765
# 128 2016-11-01  121.125079
# 129 2016-12-01  130.650794
# 130 2017-01-01  150.999206
# 131 2017-02-01  165.183654
# 132 2017-03-01  175.432836
# 133 2017-04-01  193.998507
# 134 2017-05-01  230.232857
# 135 2017-06-01  266.244828
# 136 2017-07-01  288.261905
# 137 2017-08-01  296.277778
# 138 2017-09-01  293.704225
# 139 2017-10-01  271.750000
# 140 2017-11-01  289.891892
# 141 2017-12-01  264.576271
# 142 2018-01-01  266.579710
# 143 2018-02-01  283.434211
# 144 2018-04-01  343.694118
# 145 2018-05-01  402.713571
# 146 2018-09-01  411.567164

# %%
        

df_comb_norm = df_all

df_comb_norm = df_comb_norm[['data_date', 'individuals']]
df_comb_norm = df_comb_norm.groupby(['data_date']).mean()
df_comb_norm.reset_index(inplace=True)
df_comb_norm['data_date'] = pd.to_datetime(df_comb_norm['data_date'])
# df_comb_norm = df_comb_norm.loc[df_comb_norm['data_date'] > '2014-12']
# df_comb_norm['individuals'] = df_comb_norm['individuals']/df_comb_norm['individuals'].max()

df_comb_norm.plot(x='data_date', y='individuals')

df_comb_norm
# Out:
#     data_date  individuals
# 0  2014-11-01        12524
# 1  2014-12-01        25274
# 2  2015-01-01       118051
# 3  2015-02-01       142766
# 4  2015-03-01       150181
# 5  2015-04-01       157883
# 6  2015-05-01       166750
# 7  2015-06-01       180491
# 8  2015-07-01       195715
# 9  2015-08-01       200274
# 10 2015-09-01       200782
# 11 2015-10-01       207616
# 12 2015-11-01       221591
# 13 2015-12-01       176782
# 14 2016-01-01       224416
# 15 2016-02-01       229172
# 16 2016-03-01       238141
# 17 2016-04-01       299066
# 18 2016-05-01       449319
# 19 2016-06-01       553701
# 20 2016-07-01       620260
# 21 2016-08-01       639951
# 22 2016-09-01       720078
# 23 2016-10-01       796671
# 24 2016-11-01       852278
# 25 2016-12-01       898860
# 26 2017-01-01       927898
# 27 2017-02-01       977742
# 28 2017-03-01       994638
# 29 2017-04-01      1025392
# 30 2017-05-01      1037328
# 31 2017-06-01      1053245
# 32 2017-07-01      1037894
# 33 2017-08-01      1053598
# 34 2017-09-01      1061892
# 35 2017-10-01      1067637
# 36 2017-11-01      1065094
# 37 2017-12-01      1073125
# 38 2018-01-01       785104

# %%
def predict(coef, history):
    yhat = coef[0]
    for i in range(1, len(coef)):
        yhat += coef[i] * history[-i]
    return yhat


# # split dataset
# # train autoregression
# train = np.array(df_norm['price'])
# model = AR(train)
# model_fit = model.fit(maxlag=20, disp=False)
# window = model_fit.k_ar
# coef = model_fit.params
# # walk forward over time steps in test
# history = [train[i] for i in range(len(train))]
# predictions = list()
# for t in range(len(train)):
#     yhat = predict(coef, history)
#     obs = train[t]
#     predictions.append(yhat)
#     history.append(obs)
# # error = mean_squared_error(test, predictions)
# # print('Test MSE: %.3f' % error)
# # plot

# plt.plot(train)
# plt.plot(predictions, color='red')
# # plt.show()

# print(train)
# print(predictions)


# Predict series
# intshow = 400
# intpredicts = len(df_norm['price'])
# intpred = len(df_norm['price'])
# start = 0
# model = ARMA(df_norm['price'], order=(5,0))
# model_fit = model.fit(disp=0)
# predicts = model_fit.predict(0, intpred-1)
# plt.figure(figsize=(20,5))
# # plt.plot(df.head(intshow).index, df['L_T1'].head(intshow))
# plt.plot(df.head(intshow).index, predicts[:])


# # print("MFE = ", mean_forecast_err( df[feature], predicts))
# # print("MAE = ", mean_absolute_err( df[feature], predicts))
# # stats.normaltest(model_fit.resid)

# arma_results = ARMAResults(model,model_fit.params)
# predictions = arma_results.predict(start, intpredicts, df2[' ' + feature])

# %%
# df_comb_norm individuals
# df_norm food price
from statsmodels.tsa.ar_model import AR

df_people = df_comb_norm.rename(columns={"data_date" : "date"})
df_inc = df_agg2.rename(columns={"event_date" : "date"})
# df_norm
df_new = df_people.merge(right=df_norm, on='date' )
df_new = df_new.merge(right=df_inc, on='date' )

df_new['individuals'] = df_new['individuals']/df_new['individuals'].max()
df_new['price'] = df_new['price']/df_new['price'].max()

# order_p = 5
# # model = ARMA(df_new['price'], order=(order_p,0))
# model=AR(df_new['price'])
# model_fit = model.fit(disp=0)
# arma_results = ARMAResults(model,model_fit.params)
# predictions = arma_results.predict( start = 0 , end = len(df_new['individuals'])-1, exog=df_new['individuals'][:order_p])


    
  
pyplot.plot(df_norm['date'].values[size:len(X)], test)
pyplot.plot(df_norm['date'].values[size:len(X)], predictions, color='red')

# pyplot.plot(df_new['date'], df_new['price'])
# pyplot.plot(df_new['date'], df_new['individuals'], color='green')
# pyplot.plot(df_new['date'], predictions, color='red')

# %%
from sklearn.linear_model import LinearRegression

X = df_new['price']

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

def parser(x):
    return datetime.strptime('190'+x, '%Y-%m')

df_norm.dropna(inplace=True)
X = df_norm['price'].values
print(X)
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
#     print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
# print('Test MSE: %.3f' % error)
# plot
pyplot.plot(df_norm['date'].values[size:len(X)], test)
pyplot.plot(df_norm['date'].values[size:len(X)], predictions, color='red')
# Out:
# [ 14.02790698  15.65        15.64864865  15.08888889  20.231
#   20.63225806  23.02166667  23.74344262  24.33770492  23.48050847
#   26.63518519  29.54711538  34.32604167  37.38851351  43.07642857
#   53.35890411  52.84350649  58.32323944  59.79836957  96.69681176
#  131.62102615 112.86176471 121.12507937 130.65079365 150.99920635
#  165.18365385 175.43283582 193.99850746 230.23285714 266.24482759
#  288.26190476 296.27777778 293.70422535 271.75       289.89189189
#  264.57627119 266.57971014 283.43421053 343.69411765 402.71357143
#  411.56716418]
# C:\Users\Chris\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1341: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# C:\Users\Chris\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# C:\Users\Chris\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1350: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   zf = out_full[ind]
